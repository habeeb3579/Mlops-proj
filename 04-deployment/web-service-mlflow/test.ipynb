# %%
import os

os.environ['GOOGLE_APPLICATION_CREDENTIALS']="/home/habeeb/dprof-dezoomfinal-b4d188529d18.json"

# %%
import mlflow

TRACKING_SERVER_HOST = "35.224.212.79" # fill in with the public IP
mlflow.set_tracking_uri(f"http://{TRACKING_SERVER_HOST}:5000")

# %%
from mlflow.tracking import MlflowClient
client = MlflowClient(tracking_uri=f"http://{TRACKING_SERVER_HOST}:5000")

# %%
model_name = "nyc-taxi-regressor-weighted-main4"
reg_models = client.get_registered_model(name=model_name)
for version in reg_models.latest_versions:
    print(version)
# Out:
# <ModelVersion: aliases=[], creation_timestamp=1749104212581, current_stage='Production', description='', last_updated_timestamp=1749104231278, name='nyc-taxi-regressor-weighted-main4', run_id='43fbc1c044724faaa96677ddc873104c', run_link='', source='gs://dezoomfinal-mlflow-artifacts/3/43fbc1c044724faaa96677ddc873104c/artifacts/model', status='READY', status_message=None, tags={}, user_id='', version='2'>

# %%
logged_model = 'runs:/43fbc1c044724faaa96677ddc873104c/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
loaded_model
# Out:
# ...
# mlflow.pyfunc.loaded_model:
#   artifact_path: model
#   flavor: mlflow.sklearn
#   run_id: 43fbc1c044724faaa96677ddc873104c

# %%
mlflow.register_model(logged_model, model_name)
# Out:
# Registered model 'nyc-taxi-regressor-weighted-main4' already exists. Creating a new version of this model...
# 2025/06/05 00:16:52 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: nyc-taxi-regressor-weighted-main4, version 2
# Created version '2' of model 'nyc-taxi-regressor-weighted-main4'.
# <ModelVersion: aliases=[], creation_timestamp=1749104212581, current_stage='None', description='', last_updated_timestamp=1749104212581, name='nyc-taxi-regressor-weighted-main4', run_id='43fbc1c044724faaa96677ddc873104c', run_link='', source='gs://dezoomfinal-mlflow-artifacts/3/43fbc1c044724faaa96677ddc873104c/artifacts/model', status='READY', status_message=None, tags={}, user_id='', version='2'>

# %%
client.transition_model_version_stage(
    name=model_name,
    version=2,
    stage="Production",
    archive_existing_versions=False  # archives previous versions in this stage
)
# Out:
# /tmp/ipykernel_90776/4146206833.py:1: FutureWarning: ``mlflow.tracking.client.MlflowClient.transition_model_version_stage`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/latest/model-registry.html#migrating-from-stages
#   client.transition_model_version_stage(
# <ModelVersion: aliases=[], creation_timestamp=1749104212581, current_stage='Production', description='', last_updated_timestamp=1749104231278, name='nyc-taxi-regressor-weighted-main4', run_id='43fbc1c044724faaa96677ddc873104c', run_link='', source='gs://dezoomfinal-mlflow-artifacts/3/43fbc1c044724faaa96677ddc873104c/artifacts/model', status='READY', status_message=None, tags={}, user_id='', version='2'>

# %%
client.set_registered_model_alias(model_name, "production", 2)  # assigns alias "production" to version 2

# %%
import mlflow.pyfunc
model_name2 = "nyc-taxi-regressor-weighted-main9"
model = mlflow.pyfunc.load_model(f"models:/{model_name2}@production")
model
# Out:
# ...
# mlflow.pyfunc.loaded_model:
#   artifact_path: model
#   flavor: mlflow.sklearn
#   run_id: 131087963e1f42d682b3dd1aff9230cf

# %%
mdl3 = mlflow.sklearn.load_model(f"models:/{model_name2}@production")
mdl3#.model_id
# Out:
# ...
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['PU_DO']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
# ...

# %%
mdl3.__repr__
# Out:
# <bound method BaseEstimator.__repr__ of Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['PU_DO']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
# ...

# %%
import sys
sys.path.append("/home/habeeb/Mlops-proj/02-experimental_tracking")

# %%
import pandas as pd
taxi = "green"
year = 2021
month = 3
url = f"https://d37ci6vzurychx.cloudfront.net/trip-data/{taxi}_tripdata_{year}-{month:02d}.parquet"        
print(f"Downloading data from {url}")
df_03 = pd.read_parquet(url)
df_03
# Out:
# ...
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2021-03-01 00:05:42   2021-03-01 00:14:03                  N
# 1             2  2021-03-01 00:21:03   2021-03-01 00:26:17                  N
# 2             2  2021-03-01 00:02:06   2021-03-01 00:22:26                  N
# 3             2  2021-03-01 00:24:03   2021-03-01 00:31:43                  N
# 4             1  2021-03-01 00:11:10   2021-03-01 00:14:46                  N
# ...         ...                  ...                   ...                ...
# 83822         2  2021-03-31 22:07:00   2021-03-31 22:13:00               None
# 83823         2  2021-03-31 22:56:00   2021-03-31 23:13:00               None
# 83824         2  2021-03-31 22:36:00   2021-03-31 22:45:00               None
# 83825         2  2021-03-31 23:35:00   2021-04-01 00:00:00               None
# 83826         2  2021-03-31 23:23:00   2021-03-31 23:32:00               None
#
# ...

# %%
def prepare_df(df: pd.DataFrame) -> pd.DataFrame:
    """
    Create necessary features from raw dataframe
    
    Args:
        df: Raw dataframe with taxi trip data
        
    Returns:
        pd.DataFrame: Dataframe with engineered features
    """
    # Create copy to avoid modifying the original
    df = df.copy()
    
    # Convert datetime columns
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    
    # Calculate trip duration in minutes
    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)
    
    # Filter trips with reasonable duration (1-60 minutes)
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    
    # Convert categorical columns to strings
    categorical_cols = ['PULocationID', 'DOLocationID']
    df[categorical_cols] = df[categorical_cols].astype(str)

    # Create PU_DO combined feature
    df['PU_DO'] = df['PULocationID'] + '_' + df['DOLocationID']
    
    # Extract target variable
    target = df['duration'].values
    return df, target

# %%
from sklearn.metrics import root_mean_squared_error

df_val, y_val = prepare_df(df_03)
#X_val, _ = DataProcessor().prepare_data(df_val)

# Predict
y_pred = model.predict(df_val)

# Evaluate
rmse = root_mean_squared_error(y_val, y_pred)
print(f"Validation RMSE: {rmse:.4f}")
# Out:
# Validation RMSE: 6.3727

# %%
taxi = "green"
year = 2021
month = 3
url = f"https://d37ci6vzurychx.cloudfront.net/trip-data/{taxi}_tripdata_{year}-{month:02d}.parquet"        
print(f"Downloading data from {url}")
ride = pd.read_parquet(url)

for col in ride.select_dtypes(include=["datetime64[ns]"]).columns:
    ride[col] = ride[col].astype(str)

ride.to_dict(orient='records')[:5]
# Out:
# ...
# [{'VendorID': 2,
#   'lpep_pickup_datetime': '2021-03-01 00:05:42',
#   'lpep_dropoff_datetime': '2021-03-01 00:14:03',
#   'store_and_fwd_flag': 'N',
#   'RatecodeID': 1.0,
#   'PULocationID': 83,
#   'DOLocationID': 129,
#   'passenger_count': 1.0,
#   'trip_distance': 1.56,
#   'fare_amount': 7.5,
#   'extra': 0.5,
#   'mta_tax': 0.5,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'ehail_fee': None,
#   'improvement_surcharge': 0.3,
#   'total_amount': 8.8,
#   'payment_type': 1.0,
#   'trip_type': 1.0,
#   'congestion_surcharge': 0.0},
#  {'VendorID': 2,
#   'lpep_pickup_datetime': '2021-03-01 00:21:03',
#   'lpep_dropoff_datetime': '2021-03-01 00:26:17',
#   'store_and_fwd_flag': 'N',
#   'RatecodeID': 1.0,
#   'PULocationID': 243,
#   'DOLocationID': 235,
#   'passenger_count': 1.0,
#   'trip_distance': 0.96,
#   'fare_amount': 6.0,
#   'extra': 0.5,
#   'mta_tax': 0.5,
#   'tip_amount': 0.0,
#   'tolls_amount': 0.0,
#   'ehail_fee': None,
# ...

# %%
mdl3 = mlflow.sklearn.load_model(f"models:/{model_name2}@production")

# %%
model.metadata.run_id
# Out:
# '131087963e1f42d682b3dd1aff9230cf'

# %%
# !python test.py
# Out:
# ...
# {'duration': [9.343056678771973, 6.59543514251709, 24.568103790283203, 13.901158332824707, 5.502249240875244], 'model_version': '131087963e1f42d682b3dd1aff9230cf'}
