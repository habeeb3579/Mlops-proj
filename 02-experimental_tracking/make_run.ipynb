# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS']="/home/habeeb/dprof-dezoomfinal-b4d188529d18.json"

# %%
# !make run-all
# Out:
# python -m main \
# 	--train-year 2021 --train-month 1 \
# 	--val-year 2021 --val-month 2 \
# 	--taxi green \
# 	--tracking-store gcp --db-path mlflow.db \
# 	--host localhost --port 5000 --tracking-uri http://35.224.212.79:5000 \
# 	--artifact-store local --bucket dezoomfinal-mlflow-artifacts --prefix none --artifact-location gs://dezoomfinal-mlflow-artifacts \
# 	--experiment-name nyc-taxi-exp-weighted-main8 --model-name nyc-taxi-regressor-weighted-main8 \
# 	--categorical-transformer onehot --numerical-transformer standard \
# 	--models all --max-evals 5 \
#
# 2025-06-05 01:29:54,320 - core.manager - INFO - tracking uri is: http://35.224.212.79:5000
# 2025/06/05 01:29:54 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-exp-weighted-main8' does not exist. Creating a new experiment.
# 2025-06-05 01:29:54,980 - core.experiment - INFO - Downloading training data: 2021-1
# ...

# %% [markdown]
# ## local mode

# %%
# !make run-models MODELS="LinearRegression Ridge Lasso LinearSVR RandomForest XGBoost" TRACKING_URI="http://127.0.0.1:5000"
# Out:
# python -m main \
# 	--train-year 2021 --train-month 1 \
# 	--val-year 2021 --val-month 2 \
# 	--taxi green \
# 	--tracking-store gcp --db-path mlflow.db \
# 	--host localhost --port 5000 --tracking-uri http://127.0.0.1:5000 \
# 	--artifact-store local --bucket dezoomfinal-mlflow-artifacts --prefix none --artifact-location gs://dezoomfinal-mlflow-artifacts \
# 	--experiment-name nyc-taxi-exp-weighted-main9 --model-name nyc-taxi-regressor-weighted-main9 \
# 	--categorical-transformer onehot --numerical-transformer none \
# 	--models LinearRegression Ridge Lasso LinearSVR RandomForest XGBoost --max-evals 5 \
#
# 2025-06-17 13:29:37,499 - core.manager - INFO - tracking uri is: http://127.0.0.1:5000
# 2025/06/17 13:29:37 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-exp-weighted-main9' does not exist. Creating a new experiment.
# 2025-06-17 13:29:37,847 - core.experiment - INFO - Downloading training data: 2021-1
# ...

# %%
# !make run-models \
    MODELS="LinearRegression Ridge Lasso LinearSVR RandomForest XGBoost" \
    TRACKING_URI="sqlite:///mlflow.db" \
    EXPERIMENT_NAME="nyc-taxi-exp-weighted-main11"
# Out:
# python -m main \
# 	--train-year 2021 --train-month 1 \
# 	--val-year 2021 --val-month 2 \
# 	--taxi green \
# 	--tracking-store gcp --db-path mlflow.db \
# 	--host localhost --port 5000 --tracking-uri sqlite:///mlflow.db \
# 	--artifact-store local --bucket dezoomfinal-mlflow-artifacts --prefix none --artifact-location gs://dezoomfinal-mlflow-artifacts \
# 	--experiment-name nyc-taxi-exp-weighted-main11 --model-name nyc-taxi-regressor-weighted-main9 \
# 	--categorical-transformer onehot --numerical-transformer none \
# 	--models LinearRegression Ridge Lasso LinearSVR RandomForest XGBoost --max-evals 5 \
#
# 2025-06-17 16:48:51,420 - core.manager - INFO - tracking uri is: sqlite:///mlflow.db
# 2025-06-17 16:48:51,643 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-06-17 16:48:51,643 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# ...

# %%
# !make run-models MODELS="LinearRegression Ridge Lasso LinearSVR RandomForest XGBoost"
# Out:
# python -m main \
# 	--train-year 2021 --train-month 1 \
# 	--val-year 2021 --val-month 2 \
# 	--taxi green \
# 	--tracking-store gcp --db-path mlflow.db \
# 	--host localhost --port 5000 --tracking-uri http://35.224.212.79:5000 \
# 	--artifact-store local --bucket dezoomfinal-mlflow-artifacts --prefix none --artifact-location gs://dezoomfinal-mlflow-artifacts \
# 	--experiment-name nyc-taxi-exp-weighted-main9 --model-name nyc-taxi-regressor-weighted-main9 \
# 	--categorical-transformer onehot --numerical-transformer none \
# 	--models LinearRegression Ridge Lasso LinearSVR RandomForest XGBoost --max-evals 5 \
#
# 2025-06-05 18:30:46,477 - core.manager - INFO - tracking uri is: http://35.224.212.79:5000
# 2025/06/05 18:30:47 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-exp-weighted-main9' does not exist. Creating a new experiment.
# 2025-06-05 18:30:47,418 - core.experiment - INFO - Downloading training data: 2021-1
# ...
