# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS']="/home/habeeb/dprof-dezoomfinal-b4d188529d18.json"

# %%
# !make run-all
# Out:
# mkdir -p models_newest
# python -m main \
# 	--train-year 2021 --train-month 1 \
# 	--val-year 2021 --val-month 2 \
# 	--taxi green \
# 	--tracking-store gcp --db-path mlflow.db \
# 	--host localhost --port 5000 --tracking-uri http://35.224.212.79:5000 \
# 	--artifact-store local --bucket dezoomfinal-mlflow-artifacts --prefix none --artifact-location gs://dezoomfinal-mlflow-artifacts \
# 	--experiment-name nyc-taxi-exp-weighted-main4 --model-name nyc-taxi-regressor-weighted-main4 \
# 	--categorical-transformer dict_vectorizer --numerical-transformer standard \
# 	--models all --max-evals 5 \
#
# 2025-06-04 19:57:29,943 - core.manager - INFO - tracking uri is: http://35.224.212.79:5000
# 2025/06/04 19:57:30 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-exp-weighted-main4' does not exist. Creating a new experiment.
# 2025-06-04 19:57:30,631 - core.experiment - INFO - Downloading training data: 2021-1
# ...
