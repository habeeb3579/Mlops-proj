# %%
# !make run-all
# Out:
# python -m main \
# 	--train-year 2021 \
# 	--train-month 1 \
# 	--val-year 2021 \
# 	--val-month 2 \
# 	--taxi green \
# 	--tracking-store sqlite \
# 	--db-path mlflow.db \
# 	--experiment-name nyc-taxi-exp-weighted-main2 \
# 	--model-name nyc-taxi-regressor-weighted-main2 \
# 	--categorical-transformer dict_vectorizer \
# 	--numerical-transformer standard \
# 	--models all \
# 	--max-evals 5 \
# 	 \
#
# 2025-05-15 01:24:31,911 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-05-15 01:24:31,911 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025/05/15 01:24:31 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-exp-weighted-main2' does not exist. Creating a new experiment.
# 2025-05-15 01:24:31,956 - core.experiment - INFO - Downloading training data: 2021-1
# 2025-05-15 01:24:31,983 - core.experiment - INFO - Loaded 76518 records from ./data/green_tripdata_2021-01.parquet
# ...
