# %%
import mlflow

# %%
mlflow.__version__
# Out:
# '2.22.0'

# %%
# no tracking_uri set, so we use the local path
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'file:///home/habeeb/Mlops-proj/02-experimental_tracking/homework/mlruns'

# %%
import importlib.util
import sys
import os

# Define full path to the module
module_path = "../../01-intro/NYC_trip_duration_pred.py"  # adjust as needed

# Load the module dynamically
spec = importlib.util.spec_from_file_location("NYCTaxiModule", module_path)
module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(module)


nyc = module.NYCTaxiDurationPredictor()

# %%
df_jan2301 = nyc.download_data(year=2023, month=1, taxi='yellow')
df_jan2301
# Out:
# ...
# Downloaded 3066766 records
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1               2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2               2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3               1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4               2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# ...           ...                  ...                   ...              ...
# 3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33              NaN
# 3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36              NaN
# 3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36              NaN
# 3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00              NaN
# 3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56              NaN
#
# ...

# %%
df_jan2301.to_parquet("/home/habeeb/Mlops-proj/02-experimental_tracking/data/yellow_tripdata_2023-01.parquet")

# %%
df_feb2302 = nyc.download_data(year=2023, month=2, taxi='yellow')
df_feb2302
# Out:
# ...
# Downloaded 2913955 records
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2023-02-01 00:32:53   2023-02-01 00:34:34              2.0
# 1               2  2023-02-01 00:35:16   2023-02-01 00:35:30              1.0
# 2               2  2023-02-01 00:35:16   2023-02-01 00:35:30              1.0
# 3               1  2023-02-01 00:29:33   2023-02-01 01:01:38              0.0
# 4               2  2023-02-01 00:12:28   2023-02-01 00:25:46              1.0
# ...           ...                  ...                   ...              ...
# 2913950         2  2023-02-28 23:46:00   2023-03-01 00:05:00              NaN
# 2913951         2  2023-02-28 23:26:02   2023-02-28 23:37:10              NaN
# 2913952         2  2023-02-28 23:24:00   2023-02-28 23:38:00              NaN
# 2913953         2  2023-02-28 23:03:00   2023-02-28 23:10:00              NaN
# 2913954         2  2023-02-28 23:03:03   2023-02-28 23:12:51              NaN
#
# ...

# %%
df_feb2302.to_parquet("/home/habeeb/Mlops-proj/02-experimental_tracking/data/yellow_tripdata_2023-02.parquet")

# %%
df_mar2303 = nyc.download_data(year=2023, month=3, taxi='yellow')
df_mar2303
# Out:
# ...
# Downloaded 3403766 records
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2023-03-01 00:06:43   2023-03-01 00:16:43              1.0
# 1               2  2023-03-01 00:08:25   2023-03-01 00:39:30              2.0
# 2               1  2023-03-01 00:15:04   2023-03-01 00:29:26              0.0
# 3               1  2023-03-01 00:49:37   2023-03-01 01:01:05              1.0
# 4               2  2023-03-01 00:08:04   2023-03-01 00:11:06              1.0
# ...           ...                  ...                   ...              ...
# 3403761         2  2023-03-31 23:24:25   2023-03-31 23:40:54              NaN
# 3403762         2  2023-03-31 23:24:50   2023-04-01 00:04:12              NaN
# 3403763         2  2023-03-31 23:26:31   2023-03-31 23:49:39              NaN
# 3403764         2  2023-03-31 23:07:51   2023-03-31 23:15:56              NaN
# 3403765         2  2023-03-31 23:26:12   2023-03-31 23:31:47              NaN
#
# ...

# %%
df_mar2303.to_parquet("/home/habeeb/Mlops-proj/02-experimental_tracking/data/yellow_tripdata_2023-03.parquet")

# %%
# mlflow ui --port 5000

# %%
# Out:
# 2025/05/26 14:18:41 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-experiment-homework2' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/297665865818173535', creation_time=1748290721659, experiment_id='297665865818173535', last_update_time=1748290721659, lifecycle_stage='active', name='nyc-taxi-experiment-homework2', tags={}>

# %%
# !python /home/habeeb/Mlops-proj/02-experimental_tracking/homework/preprocess_data.py --raw_data_path /home/habeeb/Mlops-proj/02-experimental_tracking/data --dest_path /home/habeeb/Mlops-proj/02-experimental_tracking/output --taxi_type yellow

# %%
# !python /home/habeeb/Mlops-proj/02-experimental_tracking/homework/train.py --data_path /home/habeeb/Mlops-proj/02-experimental_tracking/output
# Out:
# 2025/05/26 14:48:16 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-experiment-homework2' does not exist. Creating a new experiment.
# [<Experiment: artifact_location='file:///home/habeeb/Mlops-proj/02-experimental_tracking/homework/mlruns/111651531653631598', creation_time=1748292496484, experiment_id='111651531653631598', last_update_time=1748292496484, lifecycle_stage='active', name='nyc-taxi-experiment-homework2', tags={}>, <Experiment: artifact_location='file:///home/habeeb/Mlops-proj/02-experimental_tracking/homework/mlruns/0', creation_time=1748292496477, experiment_id='0', last_update_time=1748292496477, lifecycle_stage='active', name='Default', tags={}>]
# 2025/05/26 14:48:17 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: Unable to allocate 489. GiB for an array with shape (3009173, 21802) and data type float64
# ^C
#
# Aborted!

# %%
# !python /home/habeeb/Mlops-proj/02-experimental_tracking/homework/hpo.py --data_path /home/habeeb/Mlops-proj/02-experimental_tracking/output --num_trials 15
# Out:
# 100%|███████| 15/15 [1:15:25<00:00, 301.73s/trial, best loss: 5.037464215926993]

# %% [markdown]
# mlflow server \
#   --backend-store-uri sqlite:///mlflow.db \
#   --default-artifact-root ./artifacts \
#   --host 0.0.0.0 \
#   --port 5000

# %%
# !python /home/habeeb/Mlops-proj/02-experimental_tracking/homework/register_model.py --data_path /home/habeeb/Mlops-proj/02-experimental_tracking/output
# Out:
# 2025/05/26 17:14:20 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-best-models' does not exist. Creating a new experiment.
# Evaluating top 5 Hyperopt runs...
# 2025/05/26 17:21:57 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/05/26 17:26:39 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/05/26 17:39:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/05/26 17:44:06 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# ...
